# %%
import numpy as np
import pygrib
from tqdm import tqdm

# %%
import netCDF4
import xarray as xr
import pandas as pd
import matplotlib.pyplot as plt
from os.path import exists

# %%
import cartopy as cp
import cartopy.crs as ccrs
import cartopy.io.shapereader as shpreader
import cartopy.feature as cfeature
import glob

# %%
ds = xr.open_dataset('20160413/20160413_hrrr.t03z.wrfprsf00.grib2')
# Out:
# Ignoring index file '20160413/20160413_hrrr.t03z.wrfprsf00.grib2.923a8.idx' incompatible with GRIB file
# ---------------------------------------------------------------------------
# DatasetBuildError                         Traceback (most recent call last)
# ~\anaconda3\envs\hagelslag\lib\site-packages\cfgrib\dataset.py in build_dataset_components(index, errors, encode_cf, squeeze, log, read_keys, time_dims, extra_coords)
#     625         try:
# --> 626             dims, data_var, coord_vars = build_variable_components(
#     627                 var_index,
#
# ~\anaconda3\envs\hagelslag\lib\site-packages\cfgrib\dataset.py in build_variable_components(index, encode_cf, filter_by_keys, log, errors, squeeze, read_keys, time_dims, extra_coords)
#     474 ) -> T.Tuple[T.Dict[str, int], Variable, T.Dict[str, Variable]]:
# --> 475     data_var_attrs = enforce_unique_attributes(index, DATA_ATTRIBUTES_KEYS, filter_by_keys)
# ...

# %%
dsIsobar = xr.open_dataset('20160413/20160413_hrrr.t03z.wrfprsf00.grib2', filter_by_keys={'typeOfLevel': 'isobaricInhPa'})
# Out:
# Ignoring index file '20160413/20160413_hrrr.t03z.wrfprsf00.grib2.923a8.idx' incompatible with GRIB file

# %%
dsIsobar
# Out:
# <xarray.Dataset>
# Dimensions:        (isobaricInhPa: 40, x: 1799, y: 1059)
# Coordinates:
#     time           datetime64[ns] ...
#     step           timedelta64[ns] ...
#   * isobaricInhPa  (isobaricInhPa) float64 1.013e+03 1e+03 975.0 ... 75.0 50.0
#     latitude       (y, x) float64 ...
#     longitude      (y, x) float64 ...
#     valid_time     datetime64[ns] ...
# Dimensions without coordinates: x, y
# Data variables: (12/14)
#     gh             (isobaricInhPa, y, x) float32 ...
#     t              (isobaricInhPa, y, x) float32 ...
#     r              (isobaricInhPa, y, x) float32 ...
#     dpt            (isobaricInhPa, y, x) float32 ...
#     q              (isobaricInhPa, y, x) float32 ...
#     w              (isobaricInhPa, y, x) float32 ...
#     ...             ...
#     absv           (isobaricInhPa, y, x) float32 ...
#     clwmr          (isobaricInhPa, y, x) float32 ...
#     cice           (isobaricInhPa, y, x) float32 ...
# ...

# %%
ds_Surface = xr.open_dataset('20160413/20160413_hrrr.t03z.wrfprsf00.grib2', filter_by_keys={'stepType':'instant', 'typeOfLevel': 'surface'})
# Out:
# Ignoring index file '20160413/20160413_hrrr.t03z.wrfprsf00.grib2.923a8.idx' incompatible with GRIB file

# %%
ds_Surface
# Out:
# <xarray.Dataset>
# Dimensions:     (x: 1799, y: 1059)
# Coordinates:
#     time        datetime64[ns] 2016-04-13T03:00:00
#     step        timedelta64[ns] 00:00:00
#     surface     float64 0.0
#     latitude    (y, x) float64 ...
#     longitude   (y, x) float64 ...
#     valid_time  datetime64[ns] 2016-04-13T03:00:00
# Dimensions without coordinates: x, y
# Data variables: (12/22)
#     orog        (y, x) float32 ...
#     vis         (y, x) float32 ...
#     gust        (y, x) float32 ...
#     ltng        (y, x) float32 ...
#     sp          (y, x) float32 ...
#     t           (y, x) float32 ...
#     ...          ...
#     cape        (y, x) float32 ...
#     cin         (y, x) float32 ...
#     dswrf       (y, x) float32 ...
#     hpbl        (y, x) float32 ...
#     lsm         (y, x) float32 ...
#     siconc      (y, x) float32 ...
# Attributes:
#     GRIB_edition:            2
#     GRIB_centre:             kwbc
# ...

# %%
ds_Surface_accum =  xr.open_dataset('20160413/20160413_hrrr.t03z.wrfprsf00.grib2', filter_by_keys={'stepType':'accum', 'typeOfLevel': 'surface'})
# Out:
# Ignoring index file '20160413/20160413_hrrr.t03z.wrfprsf00.grib2.923a8.idx' incompatible with GRIB file

# %%
ds_Surface_accum
# Out:
# <xarray.Dataset>
# Dimensions:     (x: 1799, y: 1059)
# Coordinates:
#     time        datetime64[ns] ...
#     step        timedelta64[ns] ...
#     surface     float64 ...
#     latitude    (y, x) float64 ...
#     longitude   (y, x) float64 ...
#     valid_time  datetime64[ns] ...
# Dimensions without coordinates: x, y
# Data variables:
#     tp          (y, x) float32 ...
#     sdwe        (y, x) float32 ...
# Attributes:
#     GRIB_edition:            2
#     GRIB_centre:             kwbc
#     GRIB_centreDescription:  US National Weather Service - NCEP
#     GRIB_subCentre:          0
#     Conventions:             CF-1.7
#     institution:             US National Weather Service - NCEP
#     history:                 2021-06-29T20:36 GRIB to CDM+CF via cfgrib-0.9.9...

# %%
dsDepthbelowLandLayer = xr.open_dataset('20160413/20160413_hrrr.t03z.wrfprsf00.grib2', filter_by_keys={'typeOfLevel': 'depthBelowLandLayer'})
# Out:
# Ignoring index file '20160413/20160413_hrrr.t03z.wrfprsf00.grib2.923a8.idx' incompatible with GRIB file

# %%
dsDepthbelowLandLayer
# Out:
# <xarray.Dataset>
# Dimensions:              (depthBelowLandLayer: 9, x: 1799, y: 1059)
# Coordinates:
#     time                 datetime64[ns] ...
#     step                 timedelta64[ns] ...
#   * depthBelowLandLayer  (depthBelowLandLayer) float64 0.0 0.01 0.04 ... 1.6 3.0
#     latitude             (y, x) float64 ...
#     longitude            (y, x) float64 ...
#     valid_time           datetime64[ns] ...
# Dimensions without coordinates: x, y
# Data variables:
#     st                   (depthBelowLandLayer, y, x) float32 ...
#     soilw                (depthBelowLandLayer, y, x) float32 ...
# Attributes:
#     GRIB_edition:            2
#     GRIB_centre:             kwbc
#     GRIB_centreDescription:  US National Weather Service - NCEP
#     GRIB_subCentre:          0
#     Conventions:             CF-1.7
#     institution:             US National Weather Service - NCEP
#     history:                 2021-06-29T20:39 GRIB to CDM+CF via cfgrib-0.9.9...

# %%
dsBelowLand = xr.open_dataset('20160413/20160413_hrrr.t03z.wrfprsf00.grib2', filter_by_keys={'typeOfLevel': 'depthBelowLand'})
# Out:
# Ignoring index file '20160413/20160413_hrrr.t03z.wrfprsf00.grib2.923a8.idx' incompatible with GRIB file

# %%
dsBelowLand
# Out:
# <xarray.Dataset>
# Dimensions:         (x: 1799, y: 1059)
# Coordinates:
#     time            datetime64[ns] ...
#     step            timedelta64[ns] ...
#     depthBelowLand  float64 ...
#     latitude        (y, x) float64 ...
#     longitude       (y, x) float64 ...
#     valid_time      datetime64[ns] ...
# Dimensions without coordinates: x, y
# Data variables:
#     mstav           (y, x) float32 ...
# Attributes:
#     GRIB_edition:            2
#     GRIB_centre:             kwbc
#     GRIB_centreDescription:  US National Weather Service - NCEP
#     GRIB_subCentre:          0
#     Conventions:             CF-1.7
#     institution:             US National Weather Service - NCEP
#     history:                 2021-06-29T20:39 GRIB to CDM+CF via cfgrib-0.9.9...

# %%
dscloudTop = xr.open_dataset('20160413/20160413_hrrr.t03z.wrfprsf00.grib2', filter_by_keys={'typeOfLevel': 'cloudTop'})
# Out:
# Ignoring index file '20160413/20160413_hrrr.t03z.wrfprsf00.grib2.923a8.idx' incompatible with GRIB file

# %%
dscloudTop
# Out:
# <xarray.Dataset>
# Dimensions:     (x: 1799, y: 1059)
# Coordinates:
#     time        datetime64[ns] ...
#     step        timedelta64[ns] ...
#     cloudTop    float64 ...
#     latitude    (y, x) float64 ...
#     longitude   (y, x) float64 ...
#     valid_time  datetime64[ns] ...
# Dimensions without coordinates: x, y
# Data variables:
#     unknown     (y, x) float32 ...
#     pres        (y, x) float32 ...
#     gh          (y, x) float32 ...
# Attributes:
#     GRIB_edition:            2
#     GRIB_centre:             kwbc
#     GRIB_centreDescription:  US National Weather Service - NCEP
#     GRIB_subCentre:          0
#     Conventions:             CF-1.7
#     institution:             US National Weather Service - NCEP
#     history:                 2021-06-29T00:31 GRIB to CDM+CF via cfgrib-0.9.9...

# %%
dsheightAboveGround = xr.open_dataset('20160413/20160413_hrrr.t03z.wrfprsf00.grib2', filter_by_keys={'typeOfLevel': 'heightAboveGround'})
# Out:
# Ignoring index file '20160413/20160413_hrrr.t03z.wrfprsf00.grib2.923a8.idx' incompatible with GRIB file
# skipping variable: paramId==0 shortName='unknown'
# Traceback (most recent call last):
#   File "C:\Users\jorda\anaconda3\envs\hagelslag\lib\site-packages\cfgrib\dataset.py", line 653, in build_dataset_components
#     dict_merge(variables, coord_vars)
#   File "C:\Users\jorda\anaconda3\envs\hagelslag\lib\site-packages\cfgrib\dataset.py", line 584, in dict_merge
#     raise DatasetBuildError(
# cfgrib.dataset.DatasetBuildError: key present and new value is different: key='heightAboveGround' value=Variable(dimensions=('heightAboveGround',), data=array([1000., 4000.])) new_value=Variable(dimensions=(), data=1000.0)
# skipping variable: paramId==131 shortName='u'
# Traceback (most recent call last):
#   File "C:\Users\jorda\anaconda3\envs\hagelslag\lib\site-packages\cfgrib\dataset.py", line 653, in build_dataset_components
#     dict_merge(variables, coord_vars)
# ...

# %%
dsheightAboveGround
# Out:
# <xarray.Dataset>
# Dimensions:            (heightAboveGround: 2, x: 1799, y: 1059)
# Coordinates:
#     time               datetime64[ns] ...
#     step               timedelta64[ns] ...
#   * heightAboveGround  (heightAboveGround) float64 1e+03 4e+03
#     latitude           (y, x) float64 ...
#     longitude          (y, x) float64 ...
#     valid_time         datetime64[ns] ...
# Dimensions without coordinates: x, y
# Data variables:
#     refd               (heightAboveGround, y, x) float32 ...
# Attributes:
#     GRIB_edition:            2
#     GRIB_centre:             kwbc
#     GRIB_centreDescription:  US National Weather Service - NCEP
#     GRIB_subCentre:          0
#     Conventions:             CF-1.7
#     institution:             US National Weather Service - NCEP
#     history:                 2021-06-29T00:33 GRIB to CDM+CF via cfgrib-0.9.9...

# %%
dspressFromGround = xr.open_dataset('20160413/20160413_hrrr.t03z.wrfprsf00.grib2', filter_by_keys={'typeOfLevel': 'pressureFromGroundLayer'})
# Out:
# Ignoring index file '20160413/20160413_hrrr.t03z.wrfprsf00.grib2.923a8.idx' incompatible with GRIB file
# skipping variable: paramId==260128 shortName='lftx4'
# Traceback (most recent call last):
#   File "C:\Users\jorda\anaconda3\envs\hagelslag\lib\site-packages\cfgrib\dataset.py", line 653, in build_dataset_components
#     dict_merge(variables, coord_vars)
#   File "C:\Users\jorda\anaconda3\envs\hagelslag\lib\site-packages\cfgrib\dataset.py", line 584, in dict_merge
#     raise DatasetBuildError(
# cfgrib.dataset.DatasetBuildError: key present and new value is different: key='pressureFromGroundLayer' value=Variable(dimensions=(), data=40000.0) new_value=Variable(dimensions=(), data=18000.0)
# skipping variable: paramId==59 shortName='cape'
# Traceback (most recent call last):
#   File "C:\Users\jorda\anaconda3\envs\hagelslag\lib\site-packages\cfgrib\dataset.py", line 653, in build_dataset_components
#     dict_merge(variables, coord_vars)
# ...

# %%
dspressFromGround
# Out:
# <xarray.Dataset>
# Dimensions:                  (x: 1799, y: 1059)
# Coordinates:
#     time                     datetime64[ns] ...
#     step                     timedelta64[ns] ...
#     pressureFromGroundLayer  float64 ...
#     latitude                 (y, x) float64 ...
#     longitude                (y, x) float64 ...
#     valid_time               datetime64[ns] ...
# Dimensions without coordinates: x, y
# Data variables:
#     unknown                  (y, x) float32 ...
# Attributes:
#     GRIB_edition:            2
#     GRIB_centre:             kwbc
#     GRIB_centreDescription:  US National Weather Service - NCEP
#     GRIB_subCentre:          0
#     Conventions:             CF-1.7
#     institution:             US National Weather Service - NCEP
#     history:                 2021-06-29T00:35 GRIB to CDM+CF via cfgrib-0.9.9...

# %%
dsSigmaLayer = xr.open_dataset('20160413/20160413_hrrr.t03z.wrfprsf00.grib2', filter_by_keys={'typeOfLevel': 'sigmaLayer'})
# Out:
# Ignoring index file '20160413/20160413_hrrr.t03z.wrfprsf00.grib2.923a8.idx' incompatible with GRIB file

# %%
dsSigmaLayer
# Out:
# <xarray.Dataset>
# Dimensions:     (x: 1799, y: 1059)
# Coordinates:
#     time        datetime64[ns] ...
#     step        timedelta64[ns] ...
#     sigmaLayer  float64 ...
#     latitude    (y, x) float64 ...
#     longitude   (y, x) float64 ...
#     valid_time  datetime64[ns] ...
# Dimensions without coordinates: x, y
# Data variables:
#     wz          (y, x) float32 ...
# Attributes:
#     GRIB_edition:            2
#     GRIB_centre:             kwbc
#     GRIB_centreDescription:  US National Weather Service - NCEP
#     GRIB_subCentre:          0
#     Conventions:             CF-1.7
#     institution:             US National Weather Service - NCEP
#     history:                 2021-06-29T00:37 GRIB to CDM+CF via cfgrib-0.9.9...

# %%
dsMeanSea = xr.open_dataset('20160413/20160413_hrrr.t03z.wrfprsf00.grib2', filter_by_keys={'typeOfLevel': 'meanSea'})
# Out:
# Ignoring index file '20160413/20160413_hrrr.t03z.wrfprsf00.grib2.923a8.idx' incompatible with GRIB file

# %%
dsMeanSea
# Out:
# <xarray.Dataset>
# Dimensions:     (x: 1799, y: 1059)
# Coordinates:
#     time        datetime64[ns] ...
#     step        timedelta64[ns] ...
#     meanSea     float64 ...
#     latitude    (y, x) float64 ...
#     longitude   (y, x) float64 ...
#     valid_time  datetime64[ns] ...
# Dimensions without coordinates: x, y
# Data variables:
#     prmsl       (y, x) float32 ...
# Attributes:
#     GRIB_edition:            2
#     GRIB_centre:             kwbc
#     GRIB_centreDescription:  US National Weather Service - NCEP
#     GRIB_subCentre:          0
#     Conventions:             CF-1.7
#     institution:             US National Weather Service - NCEP
#     history:                 2021-06-29T09:25 GRIB to CDM+CF via cfgrib-0.9.9...

# %%
dsHeightAboveGLmax = xr.open_dataset('20160413/20160413_hrrr.t03z.wrfprsf00.grib2', filter_by_keys={'stepType': 'max', 'typeOfLevel': 'heightAboveGroundLayer'})
# Out:
# Ignoring index file '20160413/20160413_hrrr.t03z.wrfprsf00.grib2.923a8.idx' incompatible with GRIB file

# %%
dsHeightAboveGLmax
# Out:
# <xarray.Dataset>
# Dimensions:                 (x: 1799, y: 1059)
# Coordinates:
#     time                    datetime64[ns] ...
#     step                    timedelta64[ns] ...
#     heightAboveGroundLayer  float64 ...
#     latitude                (y, x) float64 ...
#     longitude               (y, x) float64 ...
#     valid_time              datetime64[ns] ...
# Dimensions without coordinates: x, y
# Data variables:
#     unknown                 (y, x) float32 ...
# Attributes:
#     GRIB_edition:            2
#     GRIB_centre:             kwbc
#     GRIB_centreDescription:  US National Weather Service - NCEP
#     GRIB_subCentre:          0
#     Conventions:             CF-1.7
#     institution:             US National Weather Service - NCEP
#     history:                 2021-06-29T09:31 GRIB to CDM+CF via cfgrib-0.9.9...

# %%
dsHeightAboveGLinstant = xr.open_dataset('20160413/20160413_hrrr.t03z.wrfprsf00.grib2', filter_by_keys={'stepType': 'instant', 'typeOfLevel': 'heightAboveGroundLayer'})
# Out:
# Ignoring index file '20160413/20160413_hrrr.t03z.wrfprsf00.grib2.923a8.idx' incompatible with GRIB file
# skipping variable: paramId==260070 shortName='ustm'
# Traceback (most recent call last):
#   File "C:\Users\jorda\anaconda3\envs\hagelslag\lib\site-packages\cfgrib\dataset.py", line 653, in build_dataset_components
#     dict_merge(variables, coord_vars)
#   File "C:\Users\jorda\anaconda3\envs\hagelslag\lib\site-packages\cfgrib\dataset.py", line 584, in dict_merge
#     raise DatasetBuildError(
# cfgrib.dataset.DatasetBuildError: key present and new value is different: key='heightAboveGroundLayer' value=Variable(dimensions=('heightAboveGroundLayer',), data=array([1000., 3000.])) new_value=Variable(dimensions=(), data=0.0)
# skipping variable: paramId==260071 shortName='vstm'
# Traceback (most recent call last):
#   File "C:\Users\jorda\anaconda3\envs\hagelslag\lib\site-packages\cfgrib\dataset.py", line 653, in build_dataset_components
#     dict_merge(variables, coord_vars)
# ...

# %%
dsHeightAboveGLinstant
# Out:
# <xarray.Dataset>
# Dimensions:                 (heightAboveGroundLayer: 2, x: 1799, y: 1059)
# Coordinates:
#     time                    datetime64[ns] ...
#     step                    timedelta64[ns] ...
#   * heightAboveGroundLayer  (heightAboveGroundLayer) float64 1e+03 3e+03
#     latitude                (y, x) float64 ...
#     longitude               (y, x) float64 ...
#     valid_time              datetime64[ns] ...
# Dimensions without coordinates: x, y
# Data variables:
#     hlcy                    (heightAboveGroundLayer, y, x) float32 ...
# Attributes:
#     GRIB_edition:            2
#     GRIB_centre:             kwbc
#     GRIB_centreDescription:  US National Weather Service - NCEP
#     GRIB_subCentre:          0
#     Conventions:             CF-1.7
#     institution:             US National Weather Service - NCEP
#     history:                 2021-06-29T09:35 GRIB to CDM+CF via cfgrib-0.9.9...

# %%
dsAtmosSingleLayer = xr.open_dataset('20160413/20160413_hrrr.t03z.wrfprsf00.grib2', filter_by_keys={'typeOfLevel': 'atmosphereSingleLayer'})
# Out:
# Ignoring index file '20160413/20160413_hrrr.t03z.wrfprsf00.grib2.923a8.idx' incompatible with GRIB file

# %%
dsAtmosSingleLayer
# Out:
# <xarray.Dataset>
# Dimensions:                (x: 1799, y: 1059)
# Coordinates:
#     time                   datetime64[ns] ...
#     step                   timedelta64[ns] ...
#     atmosphereSingleLayer  float64 ...
#     latitude               (y, x) float64 ...
#     longitude              (y, x) float64 ...
#     valid_time             datetime64[ns] ...
# Dimensions without coordinates: x, y
# Data variables:
#     unknown                (y, x) float32 ...
#     pwat                   (y, x) float32 ...
# Attributes:
#     GRIB_edition:            2
#     GRIB_centre:             kwbc
#     GRIB_centreDescription:  US National Weather Service - NCEP
#     GRIB_subCentre:          0
#     Conventions:             CF-1.7
#     institution:             US National Weather Service - NCEP
#     history:                 2021-06-29T09:38 GRIB to CDM+CF via cfgrib-0.9.9...

# %%
dsIsobaricLayer = xr.open_dataset('20160413/20160413_hrrr.t03z.wrfprsf00.grib2', filter_by_keys={'typeOfLevel': 'isobaricLayer'})
# Out:
# Ignoring index file '20160413/20160413_hrrr.t03z.wrfprsf00.grib2.923a8.idx' incompatible with GRIB file

# %%
dsIsobaricLayer
# Out:
# <xarray.Dataset>
# Dimensions:        (x: 1799, y: 1059)
# Coordinates:
#     time           datetime64[ns] ...
#     step           timedelta64[ns] ...
#     isobaricLayer  float64 ...
#     latitude       (y, x) float64 ...
#     longitude      (y, x) float64 ...
#     valid_time     datetime64[ns] ...
# Dimensions without coordinates: x, y
# Data variables:
#     lftx           (y, x) float32 ...
# Attributes:
#     GRIB_edition:            2
#     GRIB_centre:             kwbc
#     GRIB_centreDescription:  US National Weather Service - NCEP
#     GRIB_subCentre:          0
#     Conventions:             CF-1.7
#     institution:             US National Weather Service - NCEP
#     history:                 2021-06-29T09:44 GRIB to CDM+CF via cfgrib-0.9.9...

# %%
dsLowCloudLayer = xr.open_dataset('20160413/20160413_hrrr.t03z.wrfprsf00.grib2', filter_by_keys={'typeOfLevel': 'lowCloudLayer'})
# Out:
# Ignoring index file '20160413/20160413_hrrr.t03z.wrfprsf00.grib2.923a8.idx' incompatible with GRIB file

# %%
dsLowCloudLayer
# Out:
# <xarray.Dataset>
# Dimensions:        (x: 1799, y: 1059)
# Coordinates:
#     time           datetime64[ns] ...
#     step           timedelta64[ns] ...
#     lowCloudLayer  float64 ...
#     latitude       (y, x) float64 ...
#     longitude      (y, x) float64 ...
#     valid_time     datetime64[ns] ...
# Dimensions without coordinates: x, y
# Data variables:
#     lcc            (y, x) float32 ...
# Attributes:
#     GRIB_edition:            2
#     GRIB_centre:             kwbc
#     GRIB_centreDescription:  US National Weather Service - NCEP
#     GRIB_subCentre:          0
#     Conventions:             CF-1.7
#     institution:             US National Weather Service - NCEP
#     history:                 2021-06-29T10:38 GRIB to CDM+CF via cfgrib-0.9.9...

# %%
dsMidCloudLayer = xr.open_dataset('20160413/20160413_hrrr.t03z.wrfprsf00.grib2', filter_by_keys={'typeOfLevel': 'middleCloudLayer'})
# Out:
# Ignoring index file '20160413/20160413_hrrr.t03z.wrfprsf00.grib2.923a8.idx' incompatible with GRIB file

# %%
dsMidCloudLayer
# Out:
# <xarray.Dataset>
# Dimensions:           (x: 1799, y: 1059)
# Coordinates:
#     time              datetime64[ns] ...
#     step              timedelta64[ns] ...
#     middleCloudLayer  float64 ...
#     latitude          (y, x) float64 ...
#     longitude         (y, x) float64 ...
#     valid_time        datetime64[ns] ...
# Dimensions without coordinates: x, y
# Data variables:
#     mcc               (y, x) float32 ...
# Attributes:
#     GRIB_edition:            2
#     GRIB_centre:             kwbc
#     GRIB_centreDescription:  US National Weather Service - NCEP
#     GRIB_subCentre:          0
#     Conventions:             CF-1.7
#     institution:             US National Weather Service - NCEP
#     history:                 2021-06-29T10:40 GRIB to CDM+CF via cfgrib-0.9.9...

# %%
dsHighCloudLayer = xr.open_dataset('20160413/20160413_hrrr.t03z.wrfprsf00.grib2', filter_by_keys={'stepType': 'instant', 'typeOfLevel': 'highCLoudLayer'})
# Out:
# Ignoring index file '20160413/20160413_hrrr.t03z.wrfprsf00.grib2.923a8.idx' incompatible with GRIB file
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-25-8187a6adad50> in <module>
# ----> 1 dsHighCloudLayer = xr.open_dataset('20160413/20160413_hrrr.t03z.wrfprsf00.grib2', filter_by_keys={'stepType': 'instant', 'typeOfLevel': 'highCLoudLayer'})
#
# ~\anaconda3\envs\hagelslag\lib\site-packages\xarray\backends\api.py in open_dataset(filename_or_obj, engine, chunks, cache, decode_cf, mask_and_scale, decode_times, decode_timedelta, use_cftime, concat_characters, decode_coords, drop_variables, backend_kwargs, *args, **kwargs)
#     494
#     495     overwrite_encoded_chunks = kwargs.pop("overwrite_encoded_chunks", None)
# --> 496     backend_ds = backend.open_dataset(
#     497         filename_or_obj,
#     498         drop_variables=drop_variables,
#
# ...

# %%
dsAtmosSingleLayer = xr.open_dataset('20160413/20160413_hrrr.t03z.wrfprsf00.grib2', filter_by_keys={'typeOfLevel': 'atmosphereSingleLayer'})
# Out:
# Ignoring index file '20160413/20160413_hrrr.t03z.wrfprsf00.grib2.923a8.idx' incompatible with GRIB file

# %%
dsAtmosSingleLayer
# Out:
# <xarray.Dataset>
# Dimensions:                (x: 1799, y: 1059)
# Coordinates:
#     time                   datetime64[ns] ...
#     step                   timedelta64[ns] ...
#     atmosphereSingleLayer  float64 ...
#     latitude               (y, x) float64 ...
#     longitude              (y, x) float64 ...
#     valid_time             datetime64[ns] ...
# Dimensions without coordinates: x, y
# Data variables:
#     unknown                (y, x) float32 ...
#     pwat                   (y, x) float32 ...
# Attributes:
#     GRIB_edition:            2
#     GRIB_centre:             kwbc
#     GRIB_centreDescription:  US National Weather Service - NCEP
#     GRIB_subCentre:          0
#     Conventions:             CF-1.7
#     institution:             US National Weather Service - NCEP
#     history:                 2021-06-29T13:06 GRIB to CDM+CF via cfgrib-0.9.9...

# %%
dsCloudBase = xr.open_dataset('20160413/20160413_hrrr.t03z.wrfprsf00.grib2', filter_by_keys={'typeOfLevel': 'cloudBase'})
# Out:
# Ignoring index file '20160413/20160413_hrrr.t03z.wrfprsf00.grib2.923a8.idx' incompatible with GRIB file

# %%
dsCloudBase
# Out:
# <xarray.Dataset>
# Dimensions:     (x: 1799, y: 1059)
# Coordinates:
#     time        datetime64[ns] ...
#     step        timedelta64[ns] ...
#     cloudBase   float64 ...
#     latitude    (y, x) float64 ...
#     longitude   (y, x) float64 ...
#     valid_time  datetime64[ns] ...
# Dimensions without coordinates: x, y
# Data variables:
#     pres        (y, x) float32 ...
#     gh          (y, x) float32 ...
# Attributes:
#     GRIB_edition:            2
#     GRIB_centre:             kwbc
#     GRIB_centreDescription:  US National Weather Service - NCEP
#     GRIB_subCentre:          0
#     Conventions:             CF-1.7
#     institution:             US National Weather Service - NCEP
#     history:                 2021-06-29T13:08 GRIB to CDM+CF via cfgrib-0.9.9...

# %%
dsCloudCeiling = xr.open_dataset('20160413/20160413_hrrr.t03z.wrfprsf00.grib2', filter_by_keys={'typeOfLevel': 'cloudCeiling'})
# Out:
# Ignoring index file '20160413/20160413_hrrr.t03z.wrfprsf00.grib2.923a8.idx' incompatible with GRIB file

# %%
dsCloudCeiling
# Out:
# <xarray.Dataset>
# Dimensions:       (x: 1799, y: 1059)
# Coordinates:
#     time          datetime64[ns] ...
#     step          timedelta64[ns] ...
#     cloudCeiling  float64 ...
#     latitude      (y, x) float64 ...
#     longitude     (y, x) float64 ...
#     valid_time    datetime64[ns] ...
# Dimensions without coordinates: x, y
# Data variables:
#     gh            (y, x) float32 ...
# Attributes:
#     GRIB_edition:            2
#     GRIB_centre:             kwbc
#     GRIB_centreDescription:  US National Weather Service - NCEP
#     GRIB_subCentre:          0
#     Conventions:             CF-1.7
#     institution:             US National Weather Service - NCEP
#     history:                 2021-06-29T13:09 GRIB to CDM+CF via cfgrib-0.9.9...

# %%
dsConvectCloudLayer = xr.open_dataset('20160413/20160413_hrrr.t03z.wrfprsf00.grib2', filter_by_keys={'typeOfLevel': 'convectiveCloudLayer'})
# Out:
# Ignoring index file '20160413/20160413_hrrr.t03z.wrfprsf00.grib2.923a8.idx' incompatible with GRIB file

# %%
dsConvectCloudLayer
# Out:
# <xarray.Dataset>
# Dimensions:               (x: 1799, y: 1059)
# Coordinates:
#     time                  datetime64[ns] ...
#     step                  timedelta64[ns] ...
#     convectiveCloudLayer  float64 ...
#     latitude              (y, x) float64 ...
#     longitude             (y, x) float64 ...
#     valid_time            datetime64[ns] ...
# Dimensions without coordinates: x, y
# Data variables:
#     unknown               (y, x) float32 ...
# Attributes:
#     GRIB_edition:            2
#     GRIB_centre:             kwbc
#     GRIB_centreDescription:  US National Weather Service - NCEP
#     GRIB_subCentre:          0
#     Conventions:             CF-1.7
#     institution:             US National Weather Service - NCEP
#     history:                 2021-06-29T13:11 GRIB to CDM+CF via cfgrib-0.9.9...

# %%
dsNomTop = xr.open_dataset('20160413/20160413_hrrr.t03z.wrfprsf00.grib2', filter_by_keys={'typeOfLevel': 'nominalTop'})
# Out:
# Ignoring index file '20160413/20160413_hrrr.t03z.wrfprsf00.grib2.923a8.idx' incompatible with GRIB file

# %%
dsNomTop
# Out:
# <xarray.Dataset>
# Dimensions:     (x: 1799, y: 1059)
# Coordinates:
#     time        datetime64[ns] ...
#     step        timedelta64[ns] ...
#     nominalTop  float64 ...
#     latitude    (y, x) float64 ...
#     longitude   (y, x) float64 ...
#     valid_time  datetime64[ns] ...
# Dimensions without coordinates: x, y
# Data variables:
#     ulwrf       (y, x) float32 ...
# Attributes:
#     GRIB_edition:            2
#     GRIB_centre:             kwbc
#     GRIB_centreDescription:  US National Weather Service - NCEP
#     GRIB_subCentre:          0
#     Conventions:             CF-1.7
#     institution:             US National Weather Service - NCEP
#     history:                 2021-06-29T13:13 GRIB to CDM+CF via cfgrib-0.9.9...

# %%
dsAdiabatCondensate = xr.open_dataset('20160413/20160413_hrrr.t03z.wrfprsf00.grib2', filter_by_keys={'typeOfLevel': 'adiabaticCondensation'})
# Out:
# Ignoring index file '20160413/20160413_hrrr.t03z.wrfprsf00.grib2.923a8.idx' incompatible with GRIB file

# %%
dsAdiabatCondensate
# Out:
# <xarray.Dataset>
# Dimensions:                (x: 1799, y: 1059)
# Coordinates:
#     time                   datetime64[ns] ...
#     step                   timedelta64[ns] ...
#     adiabaticCondensation  float64 ...
#     latitude               (y, x) float64 ...
#     longitude              (y, x) float64 ...
#     valid_time             datetime64[ns] ...
# Dimensions without coordinates: x, y
# Data variables:
#     gh                     (y, x) float32 ...
# Attributes:
#     GRIB_edition:            2
#     GRIB_centre:             kwbc
#     GRIB_centreDescription:  US National Weather Service - NCEP
#     GRIB_subCentre:          0
#     Conventions:             CF-1.7
#     institution:             US National Weather Service - NCEP
#     history:                 2021-06-29T13:14 GRIB to CDM+CF via cfgrib-0.9.9...

# %%
dsEquilibrium = xr.open_dataset('20160413/20160413_hrrr.t03z.wrfprsf00.grib2', filter_by_keys={'typeOfLevel': 'equilibrium'})
# Out:
# Ignoring index file '20160413/20160413_hrrr.t03z.wrfprsf00.grib2.923a8.idx' incompatible with GRIB file

# %%
dsEquilibrium
# Out:
# <xarray.Dataset>
# Dimensions:      (x: 1799, y: 1059)
# Coordinates:
#     time         datetime64[ns] ...
#     step         timedelta64[ns] ...
#     equilibrium  float64 ...
#     latitude     (y, x) float64 ...
#     longitude    (y, x) float64 ...
#     valid_time   datetime64[ns] ...
# Dimensions without coordinates: x, y
# Data variables:
#     gh           (y, x) float32 ...
# Attributes:
#     GRIB_edition:            2
#     GRIB_centre:             kwbc
#     GRIB_centreDescription:  US National Weather Service - NCEP
#     GRIB_subCentre:          0
#     Conventions:             CF-1.7
#     institution:             US National Weather Service - NCEP
#     history:                 2021-06-29T13:15 GRIB to CDM+CF via cfgrib-0.9.9...

# %%
files = glob.glob("c:/Users/jorda/Downloads/20160413/*.grib2")
files.sort()
file_list1 = []
file_list2 = []
file_list3 = []
for file in files:
    file_list1.append(xr.open_dataset(file, filter_by_keys={'typeOfLevel': 'atmosphere'}))
    file_list2.append(xr.open_dataset(file, filter_by_keys={'stepType': 'instant', 'typeOfLevel': 'surface'}))
    file_list3.append(xr.open_dataset(file, filter_by_keys={'stepType': 'accum', 'typeOfLevel': 'surface'}))
ds_1 = xr.concat(file_list1, dim="time")
ds_2 = xr.concat(file_list2, dim="time")
ds_3 = xr.concat(file_list3, dim="time")

# %%
ref = ds_1.refc.isel(time=slice(0,23))
cape = ds_2.cape.isel(time=slice(0,23))
ltning = ds_2.ltng.isel(time=slice(0,23))
accum_precip = ds_3.tp.isel(time=slice(0,23))

# %%
ref.to_netcdf("Hrrr_all_input_2016_0413.nc")

# %%
cape.to_netcdf("Hrrr_all_input_2016_0413.nc")
ltning.to_netcdf("Hrrr_all_input_2016_0413.nc")
accum_precip.to_netcdf("Hrrr_all_input_2016_0413.nc")

# %%
ds_mrms_new = xr.Dataset(
     data_vars=dict(mesh_labels=(["x", "y"], labels)),
     coords=dict(longitude=(["x", "y"], lons),latitude=(["x", "y"], lats)))

# %%
ds_1.longitude.values.shape
# Out:
# (1059, 1799)

# %%
ds_1.latitude.values.shape
# Out:
# (1059, 1799)

# %%
ref.values.shape
# Out:
# (19, 1059, 1799)

# %%
ds_hrrr_new = xr.Dataset(
     data_vars=dict(ref=(["time", "y", "x"], ref.values), cape=(["time", "y", "x"], cape.values), ltng=(["time", "y", "x"], ltning.values), accum_precip=(["time", "y", "x"], accum_precip.values)),
     coords=dict(longitude=(["y", "x"], ds_1.longitude.values),latitude=(["y", "x"], ds_1.latitude.values),time=(["time"], ds_1.valid_time)))

# %%
ds_hrrr_new.to_netcdf("HRRR_all_input_2016_0413_0022.nc")
