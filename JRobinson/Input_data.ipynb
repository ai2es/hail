# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
import xarray as xr
import pylab as P
import math
import statistics

# %%
import numpy as np
import csv
import glob
from matplotlib import pyplot as plt
import seaborn as sns

# %%
# !ls ./gdrive/MyDrive/images_for_learning_20210713/
# Out:
# images_for_learning  images_for_learning_20210715

# %%
infiles = glob.glob('./gdrive/MyDrive/images_for_learning_20210713/images_for_learning_20210715/images_for_learning/*')
print(infiles)
# Out:
# ['./gdrive/MyDrive/images_for_learning_20210713/images_for_learning_20210715/images_for_learning/parallel_run0002_1.nc', './gdrive/MyDrive/images_for_learning_20210713/images_for_learning_20210715/images_for_learning/parallel_run0004_1.nc', './gdrive/MyDrive/images_for_learning_20210713/images_for_learning_20210715/images_for_learning/parallel_run0003_1.nc', './gdrive/MyDrive/images_for_learning_20210713/images_for_learning_20210715/images_for_learning/parallel_run0001_1.nc', './gdrive/MyDrive/images_for_learning_20210713/images_for_learning_20210715/images_for_learning/parallel_run0000_1.nc', './gdrive/MyDrive/images_for_learning_20210713/images_for_learning_20210715/images_for_learning/parallel_run0006_1.nc', './gdrive/MyDrive/images_for_learning_20210713/images_for_learning_20210715/images_for_learning/parallel_run0005_1.nc', './gdrive/MyDrive/images_for_learning_20210713/images_for_learning_20210715/images_for_learning/parallel_run0009_1.nc', './gdrive/MyDrive/images_for_learning_20210713/images_for_learning_20210715/images_for_learning/parallel_run0008_1.nc', './gdrive/MyDrive/images_for_learning_20210713/images_for_learning_20210715/images_for_learning/parallel_run0007_1.nc', './gdrive/MyDrive/images_for_learning_20210713/images_for_learning_20210715/images_for_learning/parallel_run0010_1.nc', './gdrive/MyDrive/images_for_learning_20210713/images_for_learning_20210715/images_for_learning/parallel_run0011_1.nc', './gdrive/MyDrive/images_for_learning_20210713/images_for_learning_20210715/images_for_learning/parallel_run0013_1.nc', './gdrive/MyDrive/images_for_learning_20210713/images_for_learning_20210715/images_for_learning/parallel_run0012_1.nc', './gdrive/MyDrive/images_for_learning_20210713/images_for_learning_20210715/images_for_learning/parallel_run0014_1.nc', './gdrive/MyDrive/images_for_learning_20210713/images_for_learning_20210715/images_for_learning/parallel_run0015_1.nc', './gdrive/MyDrive/images_for_learning_20210713/images_for_learning_20210715/images_for_learning/parallel_run0016_1.nc', './gdrive/MyDrive/images_for_learning_20210713/images_for_learning_20210715/images_for_learning/parallel_run0018_1.nc', './gdrive/MyDrive/images_for_learning_20210713/images_for_learning_20210715/images_for_learning/parallel_run0017_1.nc', './gdrive/MyDrive/images_for_learning_20210713/images_for_learning_20210715/images_for_learning/parallel_run0021_1.nc', './gdrive/MyDrive/images_for_learning_20210713/images_for_learning_20210715/images_for_learning/parallel_run0022_1.nc', './gdrive/MyDrive/images_for_learning_20210713/images_for_learning_20210715/images_for_learning/parallel_run0019_1.nc', './gdrive/MyDrive/images_for_learning_20210713/images_for_learning_20210715/images_for_learning/parallel_run0020_1.nc', './gdrive/MyDrive/images_for_learning_20210713/images_for_learning_20210715/images_for_learning/parallel_run0024_1.nc', './gdrive/MyDrive/images_for_learning_20210713/images_for_learning_20210715/images_for_learning/parallel_run0023_1.nc', './gdrive/MyDrive/images_for_learning_20210713/images_for_learning_20210715/images_for_learning/parallel_run0026_1.nc', './gdrive/MyDrive/images_for_learning_20210713/images_for_learning_20210715/images_for_learning/parallel_run0025_1.nc', './gdrive/MyDrive/images_for_learning_20210713/images_for_learning_20210715/images_for_learning/parallel_run0027_1.nc', './gdrive/MyDrive/images_for_learning_20210713/images_for_learning_20210715/images_for_learning/parallel_run0028_1.nc', './gdrive/MyDrive/images_for_learning_20210713/images_for_learning_20210715/images_for_learning/parallel_run0031_1.nc', './gdrive/MyDrive/images_for_learning_20210713/images_for_learning_20210715/images_for_learning/parallel_run0030_1.nc', './gdrive/MyDrive/images_for_learning_20210713/images_for_learning_20210715/images_for_learning/parallel_run0029_1.nc', './gdrive/MyDrive/images_for_learning_20210713/images_for_learning_20210715/images_for_learning/parallel_run0032_1.nc', './gdrive/MyDrive/images_for_learning_2 ...

# %%
#read in the data
ds = xr.open_mfdataset(infiles, concat_dim='n_samples',combine='nested', parallel=True)
print(ds)

#Separate the data array into ml input, ml output and metadata
output_ds = ds.mesh_90
output_array = output_ds.values
# Out:
# <xarray.Dataset>
# Dimensions:      (dim_0: 1, n_samples: 10250, x: 32, y: 32)
# Coordinates:
#     longitude    (n_samples, x, y) float64 dask.array<chunksize=(250, 32, 32), meta=np.ndarray>
#     latitude     (n_samples, x, y) float64 dask.array<chunksize=(250, 32, 32), meta=np.ndarray>
#     longitude2   (n_samples, x, y) float64 dask.array<chunksize=(250, 32, 32), meta=np.ndarray>
#     latitude2    (n_samples, x, y) float64 dask.array<chunksize=(250, 32, 32), meta=np.ndarray>
# Dimensions without coordinates: dim_0, n_samples, x, y
# Data variables: (12/23)
#     temp_sfc     (n_samples, x, y) float32 dask.array<chunksize=(250, 32, 32), meta=np.ndarray>
#     dewtemp_sfc  (n_samples, x, y) float32 dask.array<chunksize=(250, 32, 32), meta=np.ndarray>
#     w_sfc        (n_samples, x, y) float32 dask.array<chunksize=(250, 32, 32), meta=np.ndarray>
#     u_sfc        (n_samples, x, y) float32 dask.array<chunksize=(250, 32, 32), meta=np.ndarray>
#     v_sfc        (n_samples, x, y) float32 dask.array<chunksize=(250, 32, 32), meta=np.ndarray>
#     graup_sfc    (n_samples, x, y) float32 dask.array<chunksize=(250, 32, 32), meta=np.ndarray>
#     ...           ...
#     mesh         (n_samples, x, y) float64 dask.array<chunksize=(250, 32, 32), meta=np.ndarray>
#     mesh_90      (n_samples, x, y) float64 dask.array<chunksize=(250, 32, 32), meta=np.ndarray>
#     meshfrac     (n_samples, dim_0) float64 dask.array<chunksize=(250, 1), meta=np.ndarray>
#     time         (n_samples, dim_0) datetime64[ns] dask.array<chunksize=(250, 1), meta=np.ndarray>
#     lon          (n_samples, dim_0) float64 dask.array<chunksize=(250, 1), meta=np.ndarray>
#     lat          (n_samples, dim_0) float64 dask.array<chunksize=(250, 1), meta=np.ndarray>

# %%
for n_samples in range(10250):
  mesh = ds.mesh.values.ravel()
plt.show()

# %%
mesh
# Out:
# <xarray.DataArray 'mesh' (n_samples: 10250, x: 32, y: 32)>
# dask.array<concatenate, shape=(10250, 32, 32), dtype=float64, chunksize=(250, 32, 32), chunktype=numpy.ndarray>
# Coordinates:
#     longitude   (n_samples, x, y) float64 dask.array<chunksize=(250, 32, 32), meta=np.ndarray>
#     latitude    (n_samples, x, y) float64 dask.array<chunksize=(250, 32, 32), meta=np.ndarray>
#     longitude2  (n_samples, x, y) float64 dask.array<chunksize=(250, 32, 32), meta=np.ndarray>
#     latitude2   (n_samples, x, y) float64 dask.array<chunksize=(250, 32, 32), meta=np.ndarray>
# Dimensions without coordinates: n_samples, x, y
# Attributes:
#     coordinates:  quantile latitude longitude

# %%
# plot first few images
for i in range(9):
	# define subplot
	plt.subplot(330 + 1 + i)
	# plot raw pixel data
	plt.imshow(ds.mesh[i], cmap=plt.get_cmap('cividis'))

# %%
#getting the 90th percentile mesh over all the patches
for N_sample in range(10250):
  mesh_90 = ds.mesh_90.values.ravel()
  plt.show()

# %%
#Finding the appropriate bin size of the histogram
mesh.max()
# Out:
# 3.0

# %%
mesh.min()
# Out:
# 0.0

# %%
mesh
# Out:
# array([0., 0., 0., ..., 0., 0., 0.])

# %%
#loading in input array

meshfrac = ds.meshfrac.values
mesh = ds.mesh.values
time = ds.time.values
lon = ds.lon.values
lat = ds.lat.values
mesh90 = ds.mesh_90



input_ds = ds.drop(('mesh','mesh_90','meshfrac','time','lon','lat'))
variables = []
for variable in input_ds:
    variables.append(ds[variable])
    #print(variable)
input_array = np.stack(variables)

# %%
print(meshfrac)
meshfrac.min()
# Out:
# [[0.]
#  [0.]
#  [0.]
#  ...
#  [0.]
#  [0.]
#  [0.]]
# 0.0

# %%
min = meshfrac.min()
max = meshfrac.max()

max - min
# Out:
# 0.4794921875

# %%
meshfrac
# Out:
# array([[0.],
#        [0.],
#        [0.],
#        ...,
#        [0.],
#        [0.],
#        [0.]])

# %%
mesh.coordinates
# Out:
# 'quantile latitude longitude'

# %%
#Plotting histogram of mesh_90 data
N_points = mesh_90
n_bins = 101

# Generate a normal distribution, center at x=0 and y=5
x = N_points
y = .8 * x + N_points + 25

fig, ax = plt.subplots(1, sharey=True, tight_layout=True)

# We can set the number of bins with the `bins` kwarg
ax.semilogx()
ax.semilogy()
plt.xlabel("90th Percentile of MESH")
plt.title("Log Distribution of Pixels Featuring 90th Percentile MESH")
ax.hist(x, bins=n_bins)
# Out:
# (array([1.048494e+07, 2.454000e+03, 1.917000e+03, 1.304000e+03,
#         9.630000e+02, 7.270000e+02, 5.740000e+02, 4.540000e+02,
#         3.940000e+02, 2.910000e+02, 2.560000e+02, 1.810000e+02,
#         1.990000e+02, 1.470000e+02, 1.280000e+02, 1.150000e+02,
#         1.180000e+02, 9.400000e+01, 7.900000e+01, 6.300000e+01,
#         5.800000e+01, 5.500000e+01, 6.000000e+01, 4.600000e+01,
#         4.300000e+01, 2.300000e+01, 2.700000e+01, 2.200000e+01,
#         2.100000e+01, 1.600000e+01, 2.100000e+01, 1.400000e+01,
#         1.500000e+01, 1.200000e+01, 1.600000e+01, 1.600000e+01,
#         1.200000e+01, 1.200000e+01, 7.000000e+00, 1.100000e+01,
#         4.000000e+00, 1.500000e+01, 1.100000e+01, 3.000000e+00,
#         8.000000e+00, 7.000000e+00, 1.000000e+00, 5.000000e+00,
#         3.000000e+00, 3.000000e+00, 5.000000e+00, 4.000000e+00,
#         1.000000e+00, 2.000000e+00, 3.000000e+00, 1.000000e+00,
#         2.000000e+00, 2.000000e+00, 4.000000e+00, 1.000000e+00,
#         1.000000e+00, 0.000000e+00, 0.000000e+00, 1.000000e+00,
#         0.000000e+00, 0.000000e+00, 1.000000e+00, 2.000000e+00,
#         0.000000e+00, 0.000000e+00, 1.000000e+00, 1.000000e+00,
#         0.000000e+00, 0.000000e+00, 0.000000e+00, 0.000000e+00,
#         0.000000e+00, 0.000000e+00, 0.000000e+00, 0.000000e+00,
#         1.000000e+00, 0.000000e+00, 0.000000e+00, 0.000000e+00,
#         0.000000e+00, 0.000000e+00, 0.000000e+00, 0.000000e+00,
#         0.000000e+00, 1.000000e+00, 0.000000e+00, 0.000000e+00,
#         0.000000e+00, 0.000000e+00, 0.000000e+00, 0.000000e+00,
#         0.000000e+00, 0.000000e+00, 0.000000e+00, 0.000000e+00,
#         1.000000e+00]),
#  array([ 0.        ,  0.58728621,  1.17457242,  1.76185864,  2.34914485,
#          2.93643106,  3.52371727,  4.11100349,  4.6982897 ,  5.28557591,
#          5.87286212,  6.46014834,  7.04743455,  7.63472076,  8.22200697,
#          8.80929319,  9.3965794 ,  9.98386561, 10.57115182, 11.15843804,
#         11.74572425, 12.33301046, 12.92029667, 13.50758288, 14.0948691 ,
#         14.68215531, 15.26944152, 15.85672773, 16.44401395, 17.03130016,
#         17.61858637, 18.20587258, 18.7931588 , 19.38044501, 19.96773122,
#         20.55501743, 21.14230365, 21.72958986, 22.31687607, 22.90416228,
#         23.4914485 , 24.07873471, 24.66602092, 25.25330713, 25.84059334,
#         26.42787956, 27.01516577, 27.60245198, 28.18973819, 28.77702441,
#         29.36431062, 29.95159683, 30.53888304, 31.12616926, 31.71345547,
#         32.30074168, 32.88802789, 33.47531411, 34.06260032, 34.64988653,
#         35.23717274, 35.82445896, 36.41174517, 36.99903138, 37.58631759,
#         38.17360381, 38.76089002, 39.34817623, 39.93546244, 40.52274865,
#         41.11003487, 41.69732108, 42.28460729, 42.8718935 , 43.45917972,
#         44.04646593, 44.63375214, 45.22103835, 45.80832457, 46.39561078,
#         46.98289699, 47.5701832 , 48.15746942, 48.74475563, 49.33204184,
#         49.91932805, 50.50661427, 51.09390048, 51.68118669, 52.2684729 ,
#         52.85575911, 53.44304533, 54.03033154, 54.61761775, 55.20490396,
#         55.79219018, 56.37947639, 56.9667626 , 57.55404881, 58.14133503,
#         58.72862124, 59.31590745]),
#  <a list of 101 Patch objects>)

# %%
N_points = mesh
n_bins = 101

# Generate a normal distribution
x = N_points
y = .8 * x + N_points + 25

fig, ax = plt.subplots(1, sharey=True, tight_layout=True)

# We can set the number of bins with the `bins` kwarg
ax.semilogx()
ax.semilogy()
plt.xlabel("MESH Pixels")
plt.title("Log Distribution of Pixels Featuring MESH")
ax.hist(x, bins=n_bins)
# Out:
# (array([1.0480155e+07, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#         0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#         0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#         0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#         0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#         0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#         0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#         0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#         0.0000000e+00, 1.5774000e+04, 0.0000000e+00, 0.0000000e+00,
#         0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#         0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#         0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#         0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#         0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#         0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#         0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#         0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 6.9000000e+01,
#         0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#         0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#         0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#         0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#         0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#         0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#         0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#         0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#         2.0000000e+00]),
#  array([0.        , 0.02970297, 0.05940594, 0.08910891, 0.11881188,
#         0.14851485, 0.17821782, 0.20792079, 0.23762376, 0.26732673,
#         0.2970297 , 0.32673267, 0.35643564, 0.38613861, 0.41584158,
#         0.44554455, 0.47524752, 0.5049505 , 0.53465347, 0.56435644,
#         0.59405941, 0.62376238, 0.65346535, 0.68316832, 0.71287129,
#         0.74257426, 0.77227723, 0.8019802 , 0.83168317, 0.86138614,
#         0.89108911, 0.92079208, 0.95049505, 0.98019802, 1.00990099,
#         1.03960396, 1.06930693, 1.0990099 , 1.12871287, 1.15841584,
#         1.18811881, 1.21782178, 1.24752475, 1.27722772, 1.30693069,
#         1.33663366, 1.36633663, 1.3960396 , 1.42574257, 1.45544554,
#         1.48514851, 1.51485149, 1.54455446, 1.57425743, 1.6039604 ,
#         1.63366337, 1.66336634, 1.69306931, 1.72277228, 1.75247525,
#         1.78217822, 1.81188119, 1.84158416, 1.87128713, 1.9009901 ,
#         1.93069307, 1.96039604, 1.99009901, 2.01980198, 2.04950495,
#         2.07920792, 2.10891089, 2.13861386, 2.16831683, 2.1980198 ,
#         2.22772277, 2.25742574, 2.28712871, 2.31683168, 2.34653465,
#         2.37623762, 2.40594059, 2.43564356, 2.46534653, 2.4950495 ,
#         2.52475248, 2.55445545, 2.58415842, 2.61386139, 2.64356436,
#         2.67326733, 2.7029703 , 2.73267327, 2.76237624, 2.79207921,
#         2.82178218, 2.85148515, 2.88118812, 2.91089109, 2.94059406,
#         2.97029703, 3.        ]),
#  <a list of 101 Patch objects>)

# %%
n_bins = 101
  
# Creating distribution
x = meshfrac
y = .8 ** meshfrac + 25
  
# Creating histogram
fig, axs = plt.subplots(1, 1,
                        figsize=(10, 7), 
                        sharex=True,
                        sharey=True,
                        tight_layout=True)
  
axs.hist(x, bins=n_bins)
  
# Show plot
plt.xscale("log")
plt.yscale("log")
plt.xlabel("Log of Pixels featuring 90th Percentile Mesh")
plt.title("Distrubution of Input")
plt.show()

plt.savefig('./gdrive/MyDrive/Input_images/meshFrac_log.png',dpi=300)

# %%
input_array.shape
# Out:
# (17, 8250, 32, 32)

# %%
#Get the mean value of meshfrac
meshfrac.mean()
mean_mesh = meshfrac.mean()
print(mean_mesh)

#Finding the log of the mean value
math.log(mean_mesh)
# Out:
# 0.0015096227134146342
# -6.495895518040986

# %%
#Get the standard deviation
meshfrac.std()
# Out:
# 0.01627728796924291

# %%
x = meshfrac
y = .8 ** meshfrac + 25
  

  
# Show plot
plt.scatter(x, y, alpha=0.5)
plt.xscale("log")
plt.xlabel("Fraction of Pixels featuring 90th Percentile Mesh")
plt.title("Distrubution of Input")
plt.show()

# %%
#function to plot the HRRR input variable fields
def plot_patch(patches, idx = 0):
    r = idx
    keys = list(patches.variables.keys())
    keys.sort()
    fig,axes = plt.subplots(4,5,figsize=(20,15))
    axes = axes.ravel()
    for i,ax in enumerate(axes[:-1]):
        pm = ax.imshow(patches[keys[i]].values[r,:,:],cmap='cividis')
        ax.set_title(keys[i])
        plt.colorbar(pm,ax=ax,shrink=0.75)
    axes[-1].axis(False)
    plt.tight_layout()
    plt.show()

# %%
plot_patch(input_ds)

# %%
#function to plot the truth data
def plot_mesh_truth(mesh, idx = 0):
  keys = ["90th Percentile MRMS"]
  fig, axes = plt.subplots(1,2,figsize=(20,5))
  axes = axes.ravel()
  for i,ax in enumerate(axes[:-1]):
    pm = ax.imshow(mesh[idx,:,:,i],cmap = 'cividis',vmin = 0,vmax = 1)
    ax.set_title(keys[i])
    plt.colorbar(pm, ax=ax,shrink=0.60)
  axes[-1].axis(False)
  plt.tight_layout()
  plt.show()

# %%
plot_mesh_truth(mesh90)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-35-ad78ebea4ab6> in <module>()
# ----> 1 plot_mesh_truth(mesh90)
#
# <ipython-input-21-f12b29690a41> in plot_mesh_truth(mesh, idx)
#       5   axes = axes.ravel()
#       6   for i,ax in enumerate(axes[:-1]):
# ----> 7     pm = ax.imshow(mesh[idx,:,:,i],cmap = 'cividis',vmin = 0,vmax = 1)
#       8     ax.set_title(keys[i])
#       9     plt.colorbar(pm, ax=ax,shrink=0.60)
#
# /usr/local/lib/python3.7/dist-packages/xarray/core/dataarray.py in __getitem__(self, key)
#     704         else:
#     705             # xarray-style array indexing
# --> 706             return self.isel(indexers=self._item_key_to_dict(key))
#     707
#     708     def __setitem__(self, key: Any, value: Any) -> None:
#
# /usr/local/lib/python3.7/dist-packages/xarray/core/dataarray.py in _item_key_to_dict(self, key)
#     668         if utils.is_dict_like(key):
#     669             return key
# --> 670         key = indexing.expanded_indexer(key, self.ndim)
#     671         return dict(zip(self.dims, key))
#     672
#
# /usr/local/lib/python3.7/dist-packages/xarray/core/indexing.py in expanded_indexer(key, ndim)
#      44             new_key.append(k)
#      45     if len(new_key) > ndim:
# ---> 46         raise IndexError("too many indices")
#      47     new_key.extend((ndim - len(new_key)) * [slice(None)])
#      48     return tuple(new_key)
#
# IndexError: too many indices
