# %%
import xarray as xr
import matplotlib.pyplot as plt
import cartopy as cp
import cartopy.crs as ccrs
import cartopy.io.shapereader as shpreader

# %% [markdown]
# Read in the datasets from each file

# %%
ds = xr.open_dataset('unet_test_data/HRRR_allinput_0000_2200.nc')

# %% [markdown]
# Combine the datasets along the time dimension

# %%
#dsnew = xr.open_mfdataset(files, combined="nested", concat_dim="time", filter_by_keys={'typeOfLevel': 'atmosphere'})
#dsnew

# %% [markdown]
# Define reflectivity, hail, lightning, and total cloud cover

# %%
ref = ds.refc
hail = ds.hail
cape = ds.cape
extent_us_zoom = [230,300,49,20]
extent_midwest_zoom = [265,280,45,35]
states_provinces = cp.feature.NaturalEarthFeature(category='cultural',name='admin_1_states_provinces_lines',scale='50m',facecolor='none')

# %% [markdown]
# Plot 000Z 600Z, 1200Z, 1800Z to check with NEXRAD data

# %%
pref = ref.isel(time=0).plot(x="longitude", y="latitude", transform=ccrs.PlateCarree(), subplot_kws={"projection": ccrs.Orthographic(-100, 35)},cmap="Spectral_r")
pref.axes.coastlines()
pref.axes.gridlines()

plt.draw()
# Out:
# C:\Users\lkspy\anaconda3\envs\hagelslag\lib\site-packages\xarray\plot\utils.py:444: MatplotlibDeprecationWarning: Calling gca() with keyword arguments was deprecated in Matplotlib 3.4. Starting two minor releases later, gca() will take no keyword arguments. The gca() function should only be used to get the current axes, or if no axes exist, create new axes with default keyword arguments. To create a new axes with non-default arguments, use plt.axes() or plt.subplot().
#   ax = plt.gca(**kwargs)
# C:\Users\lkspy\anaconda3\envs\hagelslag\lib\site-packages\cartopy\mpl\geoaxes.py:1597: UserWarning: The input coordinates to pcolormesh are interpreted as cell centers, but are not monotonically increasing or decreasing. This may lead to incorrectly calculated cell edges, in which case, please supply explicit cell edges to pcolormesh.
#   X, Y, C, shading = self._pcolorargs('pcolormesh', *args,

# %%
pref = ref.isel(time=6).plot(x="longitude", y="latitude", transform=ccrs.PlateCarree(), subplot_kws={"projection": ccrs.Orthographic(-100, 35)})
pref.axes.coastlines()
pref.axes.gridlines()

plt.draw()
# Out:
# C:\Users\lkspy\anaconda3\envs\hagelslag\lib\site-packages\xarray\plot\utils.py:444: MatplotlibDeprecationWarning: Calling gca() with keyword arguments was deprecated in Matplotlib 3.4. Starting two minor releases later, gca() will take no keyword arguments. The gca() function should only be used to get the current axes, or if no axes exist, create new axes with default keyword arguments. To create a new axes with non-default arguments, use plt.axes() or plt.subplot().
#   ax = plt.gca(**kwargs)

# %%
pref = ref.isel(time=12).plot(x="longitude", y="latitude", transform=ccrs.PlateCarree(), subplot_kws={"projection": ccrs.Orthographic(-100, 35)})
pref.axes.coastlines()
pref.axes.gridlines()

plt.draw()

# %%
pref = ref.isel(time=18).plot(x="longitude", y="latitude", transform=ccrs.PlateCarree(), subplot_kws={"projection": ccrs.Orthographic(-100, 35)})
pref.axes.coastlines()
pref.axes.gridlines()

plt.draw()

# %% [markdown]
# Plot 2000 UTC and 2100 UTC reflectivity and hail and save plots

# %%
fig = plt.figure()
fig.set_size_inches(20,8)
p_ref_20 = ref.isel(time=20).plot(x='longitude', y='latitude', transform=ccrs.PlateCarree(), subplot_kws={"projection": ccrs.Orthographic(-100, 35)},cmap="Spectral_r",vmin=0)
p_ref_20.axes.set_extent(extent_midwest_zoom)
p_ref_20.axes.coastlines()
p_ref_20.axes.gridlines()
p_ref_20.axes.add_feature(cp.feature.BORDERS)
p_ref_20.axes.add_feature(states_provinces)
plt.savefig("2019_05_16_figures/HRRR_Reflectivity_Midwest_2000_UTC.png",bbox_inches='tight')
# Out:
# C:\Users\lkspy\anaconda3\envs\hagelslag\lib\site-packages\xarray\plot\utils.py:444: MatplotlibDeprecationWarning: Calling gca() with keyword arguments was deprecated in Matplotlib 3.4. Starting two minor releases later, gca() will take no keyword arguments. The gca() function should only be used to get the current axes, or if no axes exist, create new axes with default keyword arguments. To create a new axes with non-default arguments, use plt.axes() or plt.subplot().
#   ax = plt.gca(**kwargs)
# C:\Users\lkspy\anaconda3\envs\hagelslag\lib\site-packages\cartopy\mpl\geoaxes.py:1597: UserWarning: The input coordinates to pcolormesh are interpreted as cell centers, but are not monotonically increasing or decreasing. This may lead to incorrectly calculated cell edges, in which case, please supply explicit cell edges to pcolormesh.
#   X, Y, C, shading = self._pcolorargs('pcolormesh', *args,

# %%
fig = plt.figure()
fig.set_size_inches(20,8)
p_ref_20 = ref.isel(time=20).plot(x='longitude', y='latitude', transform=ccrs.PlateCarree(), subplot_kws={"projection": ccrs.Orthographic(-100, 35)},cmap="Spectral_r",vmin=0)
p_ref_20.axes.set_extent(extent_us_zoom)
p_ref_20.axes.coastlines()
p_ref_20.axes.gridlines()
p_ref_20.axes.add_feature(cp.feature.BORDERS)
p_ref_20.axes.add_feature(states_provinces)
plt.savefig("2019_05_16_figures/HRRR_Reflectivity_CONUS_2000_UTC.png",bbox_inches='tight')
# Out:
# C:\Users\lkspy\anaconda3\envs\hagelslag\lib\site-packages\xarray\plot\utils.py:444: MatplotlibDeprecationWarning: Calling gca() with keyword arguments was deprecated in Matplotlib 3.4. Starting two minor releases later, gca() will take no keyword arguments. The gca() function should only be used to get the current axes, or if no axes exist, create new axes with default keyword arguments. To create a new axes with non-default arguments, use plt.axes() or plt.subplot().
#   ax = plt.gca(**kwargs)

# %%
fig = plt.figure()
fig.set_size_inches(20,8)
p_ref_21 = ref.isel(time=21).plot(x='longitude', y='latitude', transform=ccrs.PlateCarree(), subplot_kws={"projection": ccrs.Orthographic(-100, 35)},cmap="Spectral_r",vmin=0)
p_ref_21.axes.set_extent(extent_midwest_zoom)
p_ref_21.axes.coastlines()
p_ref_21.axes.gridlines()
p_ref_21.axes.add_feature(cp.feature.BORDERS)
p_ref_21.axes.add_feature(states_provinces)
plt.savefig("2019_05_16_figures/HRRR_Reflectivity_Midwest_2100_UTC.png",bbox_inches='tight')

# %%
fig = plt.figure()
fig.set_size_inches(20,8)
p_ref_21 = ref.isel(time=21).plot(x='longitude', y='latitude', transform=ccrs.PlateCarree(), subplot_kws={"projection": ccrs.Orthographic(-100, 35)},cmap="Spectral_r",vmin=0)
p_ref_21.axes.set_extent(extent_us_zoom)
p_ref_21.axes.coastlines()
p_ref_21.axes.gridlines()
p_ref_21.axes.add_feature(cp.feature.BORDERS)
p_ref_21.axes.add_feature(states_provinces)
plt.savefig("2019_05_16_figures/HRRR_Reflectivity_CONUS_2100_UTC.png",bbox_inches='tight')

# %%
fig = plt.figure()
fig.set_size_inches(20,8)
p_hail_20 = hail.isel(time=20).plot(x='longitude', y='latitude', transform=ccrs.PlateCarree(), subplot_kws={"projection": ccrs.Orthographic(-100, 35)},cmap="Blues")
p_hail_20.axes.set_extent(extent_midwest_zoom)
p_hail_20.axes.coastlines()
p_hail_20.axes.add_feature(cp.feature.BORDERS)
p_hail_20.axes.add_feature(states_provinces)
plt.savefig("2019_05_16_figures/HRRR_Hail_Midwest_2000_UTC.png",bbox_inches='tight')

# %%
fig = plt.figure()
fig.set_size_inches(20,8)
p_hail_20 = hail.isel(time=20).plot(x='longitude', y='latitude', transform=ccrs.PlateCarree(), subplot_kws={"projection": ccrs.Orthographic(-100, 35)},cmap="Blues")
p_hail_20.axes.set_extent(extent_us_zoom)
p_hail_20.axes.coastlines()
p_hail_20.axes.add_feature(cp.feature.BORDERS)
p_hail_20.axes.add_feature(states_provinces)
plt.savefig("2019_05_16_figures/HRRR_Hail_CONUS_2000_UTC.png",bbox_inches='tight')

# %%
fig = plt.figure()
fig.set_size_inches(20,8)
p_hail_21 = hail.isel(time=21).plot(x='longitude', y='latitude', transform=ccrs.PlateCarree(), subplot_kws={"projection": ccrs.Orthographic(-100, 35)},cmap="Blues")
p_hail_21.axes.set_extent(extent_midwest_zoom)
p_hail_21.axes.coastlines()
p_hail_21.axes.add_feature(cp.feature.BORDERS)
p_hail_21.axes.add_feature(states_provinces)
plt.savefig("2019_05_16_figures/HRRR_Hail_Midwest_2100_UTC.png",bbox_inches='tight')

# %%
fig = plt.figure()
fig.set_size_inches(20,8)
p_hail_21 = hail.isel(time=21).plot(x='longitude', y='latitude', transform=ccrs.PlateCarree(), subplot_kws={"projection": ccrs.Orthographic(-100, 35)},cmap="Blues")
p_hail_21.axes.set_extent(extent_us_zoom)
p_hail_21.axes.coastlines()
p_hail_21.axes.add_feature(cp.feature.BORDERS)
p_hail_21.axes.add_feature(states_provinces)
plt.savefig("2019_05_16_figures/HRRR_Hail_CONUS_2100_UTC.png",bbox_inches='tight')

# %% [markdown]
# Plot the reflectivity over time

# %%
pref = ref.isel(time=[0,6,12,18]).plot(x="longitude", y="latitude", row="time", transform=ccrs.PlateCarree(), subplot_kws={"projection": ccrs.Orthographic(-100, 35)},cmap="Spectral_r")
for i in range(4):
    pref.axes[i,0].coastlines()
    pref.axes[i,0].gridlines()

plt.draw()

# %% [markdown]
# Plot the hail over time

# %%
phail = hail.isel(time=[0,6,12,18]).plot(x="longitude", y="latitude", row="time", transform=ccrs.PlateCarree(), subplot_kws={"projection": ccrs.Orthographic(-100, 35)})
for i in range(4):
    phail.axes[i,0].coastlines()
    phail.axes[i,0].gridlines()

plt.draw()

# %% [markdown]
# Plot the lightning over time

# %%
pltng = ltng.isel(time=[0,6,12,18]).plot(x="longitude", y="latitude", row="time", transform=ccrs.PlateCarree(), subplot_kws={"projection": ccrs.Orthographic(-100, 35)})
for i in range(4):
    pltng.axes[i,0].coastlines()
    pltng.axes[i,0].gridlines()

plt.draw()

# %% [markdown]
# Plot the total cloud cover over time

# %%
pcloud = cloud.isel(time=[0,6,12,18]).plot(x="longitude", y="latitude", row="time", transform=ccrs.PlateCarree(), subplot_kws={"projection": ccrs.Orthographic(-100, 35)})
for i in range(4):
    pcloud.axes[i,0].coastlines()
    pcloud.axes[i,0].gridlines()

plt.draw()

# %%
states_provinces = cp.feature.NaturalEarthFeature(category='cultural',name='admin_1_states_provinces_lines',scale='50m',facecolor='none')
pref = ref.isel(time=[0,3,6,9,12,15,18,21]).sel(x=slice(900,1300),y=slice(500,800)).plot(x="longitude", y="latitude", row="time", transform=ccrs.PlateCarree(), subplot_kws={"projection": ccrs.Orthographic(-90, 40)},cmap="Spectral_r", vmin=0)

for i in range(8):
    #pref.axes[i,0].add_geometries(us_shapes, ccrs.PlateCarree(), edgecolor='gray', facecolor='none')
    pref.axes[i,0].gridlines()
    pref.axes[i,0].add_feature(cp.feature.LAKES, edgecolor='black')
    pref.axes[i,0].add_feature(cp.feature.BORDERS, edgecolor='black')
    pref.axes[i,0].add_feature(cp.feature.LAKES)
    pref.axes[i,0].add_feature(states_provinces, edgecolor='black')
    pref.axes[i,0].coastlines()
    
plt.draw()
# Out:
# C:\Users\lkspy\anaconda3\envs\hagelslag\lib\site-packages\xarray\plot\facetgrid.py:394: UserWarning: Tight layout not applied. The left and right margins cannot be made large enough to accommodate all axes decorations.
#   self.fig.tight_layout()

# %%
phail = hail.isel(time=[0,3,6,9,12,15,18,21]).sel(x=slice(900,1300),y=slice(500,800)).plot(x="longitude", y="latitude", row="time", transform=ccrs.PlateCarree(), subplot_kws={"projection": ccrs.Orthographic(-90, 40)},cmap="YlOrBr")

for i in range(8):
    phail.axes[i,0].gridlines()
    phail.axes[i,0].add_feature(cp.feature.LAKES, edgecolor='black')
    phail.axes[i,0].add_feature(cp.feature.BORDERS, edgecolor='black')
    phail.axes[i,0].add_feature(cp.feature.LAKES)
    phail.axes[i,0].add_feature(states_provinces, edgecolor='black')
    phail.axes[i,0].coastlines()
    
plt.draw()

# %%
ds14 = xr.open_dataset('HRRR_data_2019_05_16/20190516_hrrr.t14z.wrfprsf00.grib2', filter_by_keys={'stepType': 'instant', 'typeOfLevel': 'surface'})

# %%
ds14
# Out:
# <xarray.Dataset>
# Dimensions:     (x: 1799, y: 1059)
# Coordinates:
#     time        datetime64[ns] ...
#     step        timedelta64[ns] ...
#     surface     float64 ...
#     latitude    (y, x) float64 ...
#     longitude   (y, x) float64 ...
#     valid_time  datetime64[ns] ...
# Dimensions without coordinates: x, y
# Data variables: (12/32)
#     vis         (y, x) float32 ...
#     gust        (y, x) float32 ...
#     sp          (y, x) float32 ...
#     orog        (y, x) float32 ...
#     t           (y, x) float32 ...
#     cnwat       (y, x) float32 ...
#     ...          ...
#     ulwrf       (y, x) float32 ...
#     vbdsf       (y, x) float32 ...
#     vddsf       (y, x) float32 ...
#     hpbl        (y, x) float32 ...
#     lsm         (y, x) float32 ...
#     siconc      (y, x) float32 ...
# Attributes:
#     GRIB_edition:            2
#     GRIB_centre:             kwbc
#     GRIB_centreDescription:  US National Weather Service - NCEP
# ...

# %%
ds14.cape.plot(x="longitude", y="latitude", transform=ccrs.PlateCarree(), subplot_kws={"projection": ccrs.Orthographic(-100, 35)})
# Out:
# C:\Users\lkspy\anaconda3\envs\hagelslag\lib\site-packages\xarray\plot\utils.py:444: MatplotlibDeprecationWarning: Calling gca() with keyword arguments was deprecated in Matplotlib 3.4. Starting two minor releases later, gca() will take no keyword arguments. The gca() function should only be used to get the current axes, or if no axes exist, create new axes with default keyword arguments. To create a new axes with non-default arguments, use plt.axes() or plt.subplot().
#   ax = plt.gca(**kwargs)
# C:\Users\lkspy\anaconda3\envs\hagelslag\lib\site-packages\cartopy\mpl\geoaxes.py:1597: UserWarning: The input coordinates to pcolormesh are interpreted as cell centers, but are not monotonically increasing or decreasing. This may lead to incorrectly calculated cell edges, in which case, please supply explicit cell edges to pcolormesh.
#   X, Y, C, shading = self._pcolorargs('pcolormesh', *args,
